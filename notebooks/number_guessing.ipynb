# %% [markdown]
# # Number Guessing Game

# %% [markdown]
# ## Basic Code

# %%
# BASIC

import random


# generate a random number b/w 1,100
generated_number = random.randint(1,100)

# count the number of attempts
count = 0

# run a continuous loop
while True:

    # ask the user to guess a number
    try:
        guessed_number = int(input("Guess the number (between 1 and 100): "))
    except:
        raise ValueError("Please enter a valid Integer")

    # exit the loop if numbers match, else keep asking the user to guess
    if guessed_number == generated_number:
        break
    elif guessed_number > generated_number:
        count += 1
        print(f"{guessed_number}: Too high! Try again.")
    else:
        count += 1
        print(f"{guessed_number}: Too low! Try again.")

print(f"Congratulations! You guessed the correct number {generated_number} in {count} attempts.")
# Out:
# 1: Too low! Try again.
# 50: Too high! Try again.
# 25: Too low! Try again.
# 35: Too low! Try again.
# 45: Too low! Try again.
# 48: Too high! Try again.
# 47: Too high! Try again.
# Congratulations! You guessed the correct number 46 in 7 attempts.

# %% [markdown]
# ## feature1: Allow the user to specify the minimum and maximum

# %%
# Allow the user to specify the minimum and maximum values for the number range before the game starts

import random

# ask the user to enter
min_num = int(input("Enter a min number"))
max_num = int(input(f"Enter a max number. Should be greater than {min_num}"))

try:
    if min_num < max_num:
        # generate a random number b/w 1,100
        generated_number = random.randint(min_num, max_num)
        print(generated_number)
    else:
        raise ValueError(f"Please enter a number greater than min: {min_num}")
except Exception as e:
    print(e)
# Out:
# 7

# %%
# count the number of attempts
count = 0

# run a continuous loop
while True:

    # ask the user to guess a number
    try:
        guessed_number = int(input("Guess the number (between 1 and 100): "))
    except:
        raise ValueError("Please enter a valid Integer")

    # exit the loop if numbers match, else keep asking the user to guess
    if guessed_number == generated_number:
        break
    elif guessed_number > generated_number:
        count += 1
        print(f"{guessed_number}: Too high! Try again.")
    else:
        count += 1
        print(f"{guessed_number}: Too low! Try again.")

print(f"Congratulations! You guessed the correct number {generated_number} in {count} attempts.")
# Out:
# 10: Too high! Try again.
# 5: Too low! Try again.
# 6: Too low! Try again.
# Congratulations! You guessed the correct number 7 in 3 attempts.

# %% [markdown]
# ## feature2: limits the number of guesses

# %%
# Allow the user to specify the minimum and maximum values for the number range before the game starts

import random

# ask the user to enter
min_num = int(input("Enter a min number"))
max_num = int(input(f"Enter a max number. Should be greater than {min_num}"))

try:
    if min_num < max_num:
        # generate a random number b/w 1,100
        generated_number = random.randint(min_num, max_num)
        print(generated_number)
    else:
        raise ValueError(f"Please enter a number greater than min: {min_num}")
except Exception as e:
    print(e)
# Out:
# 5

# %%
# count the number of attempts
num_of_attempts = 1
attempts_limit = 5

# run a continuous loop
for attempt in range(0, attempts_limit):
    # ask the user to guess a number
    try:
        guessed_number = int(input("Guess the number (between 1 and 100): "))
    except:
        raise ValueError("Please enter a valid Integer")

    # exit the loop if numbers match, else keep asking the user to guess
    if guessed_number == generated_number:
        print(f"Congratulations! You guessed the correct number {generated_number} in {num_of_attempts} attempts.")
        break
    elif guessed_number > generated_number:
        num_of_attempts += 1
        print(f"{guessed_number}: Too high! Try again.")
    else:
        num_of_attempts += 1
        print(f"{guessed_number}: Too low! Try again.")
else:
    print(f"you have reached the number of attempts limit of: {num_of_attempts-1}")
# Out:
# 1: Too low! Try again.
# 2: Too low! Try again.
# 3: Too low! Try again.
# 4: Too low! Try again.
# 1: Too low! Try again.
# you have reached the number of attempts limit of: 5

# %% [markdown]
# ## feature3:keeps track of the fewest attempts

# %%
# keeps track of the fewest attempts

import random

# ask the user to enter
min_num = int(input("Enter a min number"))
max_num = int(input(f"Enter a max number. Should be greater than {min_num}"))

try:
    if min_num < max_num:
        # generate a random number b/w 1,100
        generated_number = random.randint(min_num, max_num)
        print(generated_number)
    else:
        raise ValueError(f"Please enter a number greater than min: {min_num}")
except Exception as e:
    print(e)
# Out:
# 20

# %%
# track attempts leader board
from math import inf

attempts_leaderboard = +inf
attempts_leaderboard
# Out:
# inf

# %%
# count the number of attempts
num_of_attempts = 1
attempts_limit = 5

# run a continuous loop
for attempt in range(0, attempts_limit):
    # ask the user to guess a number
    try:
        guessed_number = int(input("Guess the number (between 1 and 100): "))
    except:
        raise ValueError("Please enter a valid Integer")

    # exit the loop if numbers match, else keep asking the user to guess
    if guessed_number == generated_number:
        print(f"Congratulations! You guessed the correct number {generated_number} in {num_of_attempts} attempts.")
        if num_of_attempts < attempts_leaderboard:
            attempts_leaderboard = num_of_attempts
            print(f"you are now on the leaderboard w/ lowest # of attempts: {attempts_leaderboard}")
        break
    elif guessed_number > generated_number:
        num_of_attempts += 1
        print(f"{guessed_number}: Too high! Try again.")
    else:
        num_of_attempts += 1
        print(f"{guessed_number}: Too low! Try again.")
else:
    print(f"you have reached the number of attempts limit of: {num_of_attempts-1}")
# Out:
# Congratulations! You guessed the correct number 20 in 1 attempts.
# you are now on the leaderboard w/ lowest # of attempts: 1
