# %% [markdown]
# # [8. Tic Tac Toe Game]

# %% [markdown]
# - Write a program to create a classic Tic Tac Toe game. Two players take turns marking Xs and Os on a 3x3 grid. The first player to align three of their marks either vertically, horizontally, or diagonally wins the game.
#
# - The board is printed after each move, with colored marks to distinguish between the players. The game checks for a winner after each move and ends when a player wins or when the board is full, resulting in a draw.

# %% [raw]
# Player O's turn
# Enter row (0-2): 1
# Enter column (0-2): 1
#
# ---+---+---
#  O |   |
# ---+---+---
#    | X |
# ---+---+---
#    |   |
# ---+---+---
#
# Player X's turn
# Enter row (0-2):

# %% [markdown]
# ## basic code

# %% [markdown]
# ## improve basic code

# %% [markdown]
# ## modularize (functions)

# %% [markdown]
# ## refactor (convert into .py file - ready for production)

# %% [markdown]
# ## VIDEO - SOLUTION

# %% [markdown]
# ## feature1:
#
# - Add a scoring system that tracks the number of games won by each player across multiple rounds.

# %% [markdown]
# ## feature2:
#
# - Allow players to start a new game without restarting the program.

# %% [markdown]
# ## feature3:
#
# - Modify the game to allow different board sizes (e.g., 44 or 55 for a more challenging experience.
